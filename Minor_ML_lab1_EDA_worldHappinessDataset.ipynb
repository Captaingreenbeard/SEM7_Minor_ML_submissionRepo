# %% [markdown]
# <a href="https://colab.research.google.com/github/Captaingreenbeard/SEM7_Minor_ML_submissionRepo/blob/main/Minor_ML_lab1_EDA_worldHappinessDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
sb.set()
sb.set_style('whitegrid')

# %%
#dataset link: https://docs.google.com/spreadsheets/d/1Cwl7jlB6hPLMfs8RKdOytbcCxrajoFlt/edit?usp=share_link&ouid=116341799080758335088&rtpof=true&sd=true
data = pd.read_csv("worldHappinessDataset_DataForFigure21WHR2021C2.csv")

# %%
data.shape
# Out:
# (149, 20)

# %%
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
data.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
data.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
#removing uncessary columns with insignificant infomation or redundant information
data.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual' ],axis=1,inplace=True)

# %%
data.shape
# Out:
# (149, 10)

# %%
data.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia
# ...

# %%
data.value_counts()
# Out:
# Country name               Regional indicator           Ladder score  Logged GDP per capita  Social support  Healthy life expectancy  Freedom to make life choices  Generosity  Perceptions of corruption  Ladder score in Dystopia
# Afghanistan                South Asia                   2.523         7.695                  0.463           52.493                   0.382                         -0.102      0.924                      2.43                        1
# Namibia                    Sub-Saharan Africa           4.574         9.161                  0.818           56.799                   0.719                         -0.149      0.847                      2.43                        1
# Netherlands                Western Europe               7.464         10.932                 0.942           72.400                   0.913                          0.175      0.338                      2.43                        1
# ...

# %%
data.nunique()
# Out:
# Country name                    149
# Regional indicator               10
# Ladder score                    147
# Logged GDP per capita           148
# Social support                  119
# Healthy life expectancy         135
# Freedom to make life choices    126
# Generosity                      130
# Perceptions of corruption       130
# Ladder score in Dystopia          1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  149 non-null    object
#  1   Regional indicator            149 non-null    object
#  2   Ladder score                  149 non-null    float64
#  3   Logged GDP per capita         149 non-null    float64
#  4   Social support                149 non-null    float64
#  5   Healthy life expectancy       149 non-null    float64
#  6   Freedom to make life choices  149 non-null    float64
#  7   Generosity                    149 non-null    float64
#  8   Perceptions of corruption     149 non-null    float64
#  9   Ladder score in Dystopia      149 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 11.8+ KB

# %%
data.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.532839               9.432208        0.814745
# std        1.073924               1.158601        0.114889
# min        2.523000               6.635000        0.463000
# 25%        4.852000               8.541000        0.750000
# 50%        5.534000               9.569000        0.832000
# 75%        6.255000              10.421000        0.905000
# max        7.842000              11.647000        0.983000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               149.000000                    149.000000  149.000000
# mean                 64.992799                      0.791597   -0.015134
# std                   6.762043                      0.113332    0.150657
# min                  48.478000                      0.382000   -0.288000
# ...

# %%
# lets see as to how clean is the dataset
data.isnull().sum()
# Out:
# Country name                    0
# Regional indicator              0
# Ladder score                    0
# Logged GDP per capita           0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Ladder score in Dystopia        0
# dtype: int64

# %%
correl = data.corr()

# %%
sb.heatmap(correl,xticklabels=correl.columns, yticklabels=correl.columns, annot=True)

# %% [markdown]
# From the above heatmap we are able to gauge that the happiness score of a country is chiefly dependent on these componenets:
#
# Strongly positively correlated:
# *   GDP per capital (0.79)
# *   Social Support (0.76)
# *   Healthy Life expenctancy (0.77)
# *   Freedom to make life choices (0.61)
#
# Significant negative correlation:
# *   Perceptions of curruption (-0.42)
#
# Beyond this, we see a significant positive correlation between the {GDP per capital, Social Support, Healthy Life expenctancy}. Let us investigate this further...

# %%
sb.pairplot(data)

# %% [markdown]
# Now, let us investigate the distribution of the various attributes of the data

# %%
data.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia'],
#       dtype='object')

# %%
data.rename(columns = {'Ladder score':'HappyScore'}, inplace = True)
data.rename(columns = {'Logged GDP per capita':'GDPperCapita'}, inplace = True)
data.rename(columns = {'Social support':'SocialSupport'}, inplace = True)
data.rename(columns = {'Ladder score':'HappyScore'}, inplace = True)
data.rename(columns = {'Healthy life expectancy':'HealthyLifeExpectancy'}, inplace = True)
data.rename(columns = {'Perceptions of corruption':'PerceptionsOfCorruption'}, inplace = True)

# %%
sb.distplot(data.HappyScore)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(data.GDPperCapita)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(data.SocialSupport)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(data.HealthyLifeExpectancy)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(data.PerceptionsOfCorruption)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.jointplot(x="HappyScore", y="GDPperCapita", data=data, kind="kde")

# %%
data.rename(columns = {'Regional indicator':'RegionalIndicator'}, inplace = True)

# %%
sb.catplot(y='RegionalIndicator', x = 'HappyScore', data = data, height= 9)

# %% [markdown]
# This graph graphically gives us an idea of which are the poorest regions, as well as how they lag behind in the happyness score. At higher end of the spectrum we have Europe, followed by NA; while on the other hand we have Sub-Saharan Africa and South Asia.

# %%
data.columns
# Out:
# Index(['Country name', 'RegionalIndicator', 'HappyScore', 'GDPperCapita',
#        'SocialSupport', 'HealthyLifeExpectancy',
#        'Freedom to make life choices', 'Generosity', 'PerceptionsOfCorruption',
#        'Ladder score in Dystopia'],
#       dtype='object')

# %% [markdown]
# Let us now investigate how the distribution of the significantly correlated factors are wrt the region within which the country is located

# %%
sb.catplot(y='HappyScore', x = 'GDPperCapita', data = data, height= 9)

# %%
sb.catplot(y='RegionalIndicator', x = 'GDPperCapita', data = data, height= 9)

# %% [markdown]
# we see an anomaly wherein the South Asian countries despite being higher than most sub-saharan coutnries in terms of their GDP per capita, they still come within same happyness score band as sub-saharan afcrican coutnries.
#
# This could mean that despite their economic standing, there could be other factors leading the lower happyness score band of south asian countries

# %%
sb.catplot(y='RegionalIndicator', x = 'SocialSupport', data = data, height= 9)

# %% [markdown]
# We see that the social support range of sub saharan africa, has the same range as South Asia; which could be one of the factors which can explain the anamaly  of them having similar happyness score band as sub-saharan africa countries

# %%
sb.catplot(y='RegionalIndicator', x = 'HealthyLifeExpectancy', data = data, height= 9)

# %% [markdown]
# We again see a bucking of the trend whernin the sub-saharan african countries have significantly lower healthy life expectancies. And despite this they in the comparable happy score band as south asian countries, which have significantly higher healthy life expectancy.

# %%
sb.catplot(y='RegionalIndicator', x = 'PerceptionsOfCorruption', data = data, height= 9)

# %% [markdown]
# We see a huge differntiator between Western Europe and NA, and the rest of the
# regions. We can see that the other contries are struggling to catch up with them on the curruption parameter. This could have been the key differentior which endows western europe and NA with signficantly higher hapyness score, despuite them being in the same range band as middle east, lating america, central europe in the other parameters which we examined above(gdp, life span, social support).

# %% [markdown]
# Let us examine the box plots to gauge more insights into the distributions of the data

# %%
sb.catplot(y='RegionalIndicator', x = 'HappyScore', kind='box', data = data,height= 9 )

# %%
sb.catplot(y='RegionalIndicator', x = 'GDPperCapita', kind='box', data = data,height= 9 )

# %%
sb.catplot(y='RegionalIndicator', x = 'SocialSupport', kind='box', data = data,height= 9 )

# %%
sb.catplot(y='RegionalIndicator', x = 'HealthyLifeExpectancy', kind='box', data = data,height= 9 )

# %%
sb.catplot(y='RegionalIndicator', x = 'PerceptionsOfCorruption', kind='box', data = data,height= 9 )

# %% [markdown]
# Let us now explore the parameters by trying to color them according to the signfiicantly correlated parameters

# %%
sb.pairplot(data, hue='HappyScore')

# %%
sb.pairplot(data, hue='GDPperCapita')

# %%
sb.pairplot(data, hue='RegionalIndicator')

# %% [markdown]
# **Let us examine the intersing correlations one on one**

# %%
sb.relplot(x = 'HappyScore', y= 'GDPperCapita', hue='RegionalIndicator', data=data)

# %%
sb.relplot(x = 'HappyScore', y= 'SocialSupport', hue='RegionalIndicator', data=data)

# %%
sb.relplot(x = 'HappyScore', y= 'HealthyLifeExpectancy', hue='RegionalIndicator', data=data)

# %%
sb.relplot(x = 'HappyScore', y= 'PerceptionsOfCorruption', hue='RegionalIndicator', data=data)

# %%
sb.relplot(x = 'SocialSupport', y= 'HealthyLifeExpectancy', hue='GDPperCapita', data=data)

# %% [markdown]
# We see a corroboration of our conviction that the social support, healthy life expectncy and the GDP per capital we all in positive corelation wrt each other

# %%
data.columns
# Out:
# Index(['Country name', 'RegionalIndicator', 'HappyScore', 'GDPperCapita',
#        'SocialSupport', 'HealthyLifeExpectancy',
#        'Freedom to make life choices', 'Generosity', 'PerceptionsOfCorruption',
#        'Ladder score in Dystopia'],
#       dtype='object')

# %%
sb.relplot(x = 'HappyScore', y= 'GDPperCapita', hue='PerceptionsOfCorruption', data=data)

# %% [markdown]
# we see an abberation here. despite the perceptions of corruptions ebing higher for nearly all the countries in the middle of the spectrum, we see that they still score higher on the happy score. This could point to the fact that the GDP per capital matters signficiantly more than the corruption perception

# %% [markdown]
# This same overpowering corruption trend continues by the social support and the healthy life factors

# %%
sb.relplot(x = 'HappyScore', y= 'SocialSupport', hue='PerceptionsOfCorruption', data=data)

# %%
sb.relplot(x = 'HappyScore', y= 'HealthyLifeExpectancy', hue='PerceptionsOfCorruption', data=data)

# %% [markdown]
# the overpowering is significantly more pronounced here

# %% [markdown]
# From the above expriemntation and visualization of the data, these were the key takeaways about the factors affecting the happiness of a country's citizens:
# * The key factors positively affecting the happiness of a country's citizens is:
#     1. Per capita GDP
#     2. Social support
#     3. Heathly life expectancy
#     4. freedom to make life choices
#
# * The key facotor negatively affecting the happyness score
#     1. perceptions of corruption
#
# We concluded on the factors by performing correlation analysis, as well as visulizing these factors wrt each other and the hapyness score
#
# *   We also saw the anamoly of sub saharan african countries having the happyiness scores in the same range of suth asian couties, despite them having signficantly larger GDP per capita. It was then observed that the south asian countries had similar ranges of perceptions of currouption as the sub saharan african countries
#
# * Although the perception of curruption is a negative factor, but it is overpowered by the factors of GDP per capita, social security, and healthy life expectany; as seen in the correlation scores as well as the pairplot visualizations
#
# * We see a huge differntiator between Western Europe and NA, and the rest of the regions, on the perceptions of curruption parameter. We can see that the other contries are struggling to catch up with them on the curruption parameter. This could have been the key differentior which endows western europe and NA with signficantly higher happiness score, despite them being in the same range band as middle east, lating america, central europe in the other parameters which we examined above(gdp, life span, social support).

# %%
#visualizing dataset in 3D
import re, seaborn as sns, numpy as np, pandas as pd, random
from pylab import *
from matplotlib.pyplot import plot, show, draw, figure, cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
sns.set_style("whitegrid", {'axes.grid' : False})

fig = plt.figure(figsize=(6,6))

ax = Axes3D(fig) # Method 1
# ax = fig.add_subplot(111, projection='3d') # Method 2

z = data['HappyScore']
x = data['GDPperCapita']
y = data['SocialSupport']


ax.scatter(x, y, z, c=x, marker='o')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
# cleaning the dataset (removing the outliers) for better analysis by machine learning techniques

# %%
sb.catplot(y='RegionalIndicator', x = 'GDPperCapita', data = data, height= 9)

# %%
data.columns
# Out:
# Index(['Country name', 'RegionalIndicator', 'HappyScore', 'GDPperCapita',
#        'SocialSupport', 'HealthyLifeExpectancy',
#        'Freedom to make life choices', 'Generosity', 'PerceptionsOfCorruption',
#        'Ladder score in Dystopia'],
#       dtype='object')

# %%
data.rename(columns = {'Country name':'CountryName'}, inplace = True)

# %%
data = data.set_index('CountryName')

# %%
data.head()
# Out:
#             RegionalIndicator  HappyScore  GDPperCapita  SocialSupport  \
# CountryName
# Finland        Western Europe       7.842        10.775          0.954
# Denmark        Western Europe       7.620        10.933          0.954
# Switzerland    Western Europe       7.571        11.117          0.942
# Iceland        Western Europe       7.554        10.878          0.983
# Netherlands    Western Europe       7.464        10.932          0.942
#
#              HealthyLifeExpectancy  Freedom to make life choices  Generosity  \
# CountryName
# Finland                       72.0                         0.949      -0.098
# Denmark                       72.7                         0.946       0.030
# Switzerland                   74.4                         0.919       0.025
# Iceland                       73.0                         0.955       0.160
# Netherlands                   72.4                         0.913       0.175
#
# ...

# %%
#dropping outlier country instances which can calue problems in the modelling section of data analysis
data = data.drop('Yemen')
data = data.drop('Palestinian Territories')
data = data.drop('Morocco')
data = data.drop('United Arab Emirates')
data = data.drop('Nicaragua')
data = data.drop('Honduras')
data = data.drop('Haiti')
data = data.drop('Singapore')
data = data.drop('Uzbekistan')
data = data.drop('Kyrgyzstan')
data = data.drop('Tajikistan')
data = data.drop('Malawi')
data = data.drop('Burundi')
data = data.drop('North Cyprus')
data = data.drop('Greece')
data = data.drop('Cyprus')
data = data.drop('Iraq')
data = data.drop('Iran')
data = data.drop('Tunisia')
data = data.drop('Armenia')
data = data.drop('Georgia')
data = data.drop('Israel')
data = data.drop('Mauritius')
data = data.drop('Pakistan')

# %%
sb.catplot(y='RegionalIndicator', x = 'GDPperCapita', data = data, height= 9)

# %% [markdown]
# We can see that the outlier countries (outlier on the basis of their aberrant GDP, social security, and heathly life span score) have been eliminated
